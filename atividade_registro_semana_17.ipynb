# %% [markdown]
# # **Registros da Semana 17**

# %% [markdown]
# # **Analise os registros a seguir:**
#
# Cada registro está com uma média de 80 a 90% concluído.
#
# Verifique o que deve ser mudado no "****" para corrigir o código e funcionalo.

# %%
# S17 – Aula 1 – Registro


cargo = input("Digite o cargo do funcionário (gerente, analista, estagiário): ").strip().lower()

dia = input("Digite o dia da semana (segunda-feira, sábado, etc.): ").strip().lower()

if cargo **** "gerente":
    if dia **** "segunda-feira" or dia **** "terça-feira" or dia **** "quarta-feira" or dia **** "quinta-feira" or dia **** "sexta-feira":
        print("Acesso permitido")
    else:
        print("Acesso negado")
elif cargo **** "analista":
    if dia **** "segunda-feira" or dia **** "terça-feira" or dia **** "quarta-feira" or dia **** "quinta-feira" or dia **** "sexta-feira":
        print("Acesso permitido")
    else:
        print("Acesso negado")
elif cargo **** "estagiário":
    if dia **** "segunda-feira" or dia **** "terça-feira" or dia **** "quarta-feira" or dia **** "quinta-feira":
        print("Acesso permitido")
    else:
        print("Acesso negado")
else:
    print("Cargo desconhecido")
# Out:
#   File "<ipython-input-1-fc6da3787b52>", line 8
#     if cargo **** "gerente":
#                ^
# SyntaxError: invalid syntax

# %%
# S17 – Aula 2 – Registro


distancia = int(input())
combustivel = float(input())

consumo_medio = distancia / combustivel

print(f"{****.3f} km/l")

# %%
# S17 – Aula 3 – Registro


def recomendar_sala(participantes, tipo_reuniao):

    if participantes **** 0:
        return "Número de participantes não pode ser negativo."

    if tipo_reuniao not in ["normal", "executiva"]:
        return "Tipo de reunião inválido. Deve ser 'normal' ou 'executiva'."

    if tipo_reuniao **** "executiva":
        return "Sala Grande"
    elif participantes **** 5:
        return "Sala Pequena"
    elif participantes **** 15:
        return "Sala Média"
    else:
        return "Sala Grande"


participantes = int(input("Digite o número de participantes: "))
tipo_reuniao = input("Digite o tipo de reunião ('normal' ou 'executiva'): ").strip().lower()

recomendacao = recomendar_sala(participantes, tipo_reuniao)
print(f"Recomendação: {recomendacao}")

# %%
# S17 – Aula 4 – Registro


def classificar_pedido(valor_pedido, dias_para_entrega):
    # Lógica de classificação
    if valor_pedido **** 500 or dias_para_entrega < 4:
        return "Urgente"
    elif 100 **** valor_pedido **** 500 or 4 **** dias_para_entrega **** 7:
        return "Prioritário"
    else:
        return "Normal"


valor_pedido = float(input("Digite o valor do pedido: "))
dias_para_entrega = int(input("Digite os dias restantes para a entrega: "))


categoria = classificar_pedido(valor_pedido, dias_para_entrega)
print(f"Categoria do pedido: {categoria}")
